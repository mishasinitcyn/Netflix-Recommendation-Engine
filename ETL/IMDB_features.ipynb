# %% [markdown]
# # IMDB Feature Extraction
# In this notebook we extract movie features from [IMDB datasets](https://datasets.imdbws.com/) to map directly to the Netflix Prize dataset by adapting scripts from [this article by Ilya Grigorik](https://www.igvita.com/2007/01/27/correlating-netflix-and-imdb-datasets/). Each movie is mapped to an array of feature ids, which map to a wide variety of features (director, actor, composer, genre, decade, etc)
#
# This notebook produces two pickle files (where n is the minimum feature count threshold):
# 1. `feature_mapping_{n}.pickle` (maps new serialized feature id's to feature)
# 2. `feature_frequencies_{n}.pickle` (maps the feature id's to their counts)
# 3. `movie_features_{n}.pickle` (maps each Netflix movie id to an array of feature id's)

# %%
import pandas as pd
import numpy as np
import gzip
from fuzzywuzzy import fuzz, process
import itertools
from typing import Dict, Set, Any
import pickle
import os
import json
from collections import Counter

# %%
DATA_PATH = "../data"
NETFLIX_FOLDER_PATH = os.path.join(DATA_PATH, "netflix_prize")
IMDB_FOLDER_PATH = os.path.join(DATA_PATH, "imdb")

# %% [markdown]
# ## Utils
# `load_netflix_titles()`
# - You guessed it, loads netflix movie_titles.txt
#
# `load_imdb_data()`
# - Loads all the IMDB datasets (name, title.basics, title.crew, title.principals, title.akas)
# - Only keep movies, TV show seasons and episodes, concerts, etc. are out of scope
#
# `FeatureExtractor`
# - Assigns id's to each feature in the IMDB dataset
# - Counts the occurrences of each feature for each movie, mapping movies with features

# %%
def load_netflix_titles() -> Dict[int, Dict[str, str]]:
    """Load Netflix Prize movie titles"""
    netflix_titles = {}
    netflix_titles_path = os.path.join(NETFLIX_FOLDER_PATH, "movie_titles.txt")
    
    with open(netflix_titles_path, 'r', encoding='latin-1') as f:
        for line in f:
            movie_id, year, title = line.strip().split(',', 2)
            netflix_titles[int(movie_id)] = {
                'title': title,
                'year': year
            }
    return netflix_titles

def load_imdb_data() -> Dict[str, pd.DataFrame]:
    """Load all required IMDB datasets"""
    datasets = {
        'names': 'name.basics.tsv.gz',
        'titles': 'title.basics.tsv.gz',
        'crew': 'title.crew.tsv.gz',
        'principals': 'title.principals.tsv.gz'
    }
    
    data = {}
    for key, filename in datasets.items():
        file_path = os.path.join(IMDB_FOLDER_PATH, filename)
        with gzip.open(file_path, 'rt', encoding='utf-8') as f:
            data[key] = pd.read_csv(f, sep='\t', na_values='\\N')
    
    # Filter titles to movies only
    data['movies'] = data['titles'][data['titles']['titleType'] == 'movie']
    
    return data

# %%
class FeatureExtractor:
    def __init__(self, imdb_data: Dict[str, pd.DataFrame], netflix_to_imdb: Dict[int, str]):
        print("Initializing FeatureExtractor...")
        self.feature_id_counter = itertools.count(1)
        self.feature_to_id: Dict[str, int] = {}
        self.feature_counts: Dict[str, int] = {}
        
        # Get the set of IMDB IDs we actually need
        relevant_imdb_ids = set(netflix_to_imdb.values())
        print(f"Filtering data for {len(relevant_imdb_ids)} matched movies...")
        
        # Convert startYear to numeric
        imdb_data['movies']['startYear'] = pd.to_numeric(imdb_data['movies']['startYear'], errors='coerce')
        
        # Filter out movies after 2005 and create index
        movies_mask = (
            (imdb_data['movies']['startYear'] <= 2005) & 
            (imdb_data['movies']['tconst'].isin(relevant_imdb_ids))
        )
        self.movies = imdb_data['movies'][movies_mask].set_index('tconst')
        print(f"Filtered movies to {len(self.movies)} entries")
        
        # Filter and index crew data
        self.crew = imdb_data['crew'][imdb_data['crew']['tconst'].isin(relevant_imdb_ids)].set_index('tconst')
        print(f"Filtered crew data to {len(self.crew)} entries")
        
        # Get relevant person IDs from crew data
        person_ids = set()
        for crew_row in self.crew.itertuples():
            for role in ['directors', 'writers']:
                if hasattr(crew_row, role) and pd.notna(getattr(crew_row, role)):
                    person_ids.update(getattr(crew_row, role).split(','))
        
        # Filter principals and get additional person IDs
        relevant_principals = imdb_data['principals'][
            imdb_data['principals']['tconst'].isin(relevant_imdb_ids)
        ]
        person_ids.update(relevant_principals['nconst'].dropna().unique())
        
        # Filter and index names data to only relevant people
        self.names = imdb_data['names'][imdb_data['names']['nconst'].isin(person_ids)].set_index('nconst')
        print(f"Filtered names data to {len(self.names)} entries")
        
        # Create principals lookup dictionary
        print("Creating principals mappings...")
        self.principals_dict = {}
        category_mapping = {
            'actor': 'Cast',
            'actress': 'Cast',
            'producer': 'Producer',
            'composer': 'Composer'
        }
        
        for _, row in relevant_principals.iterrows():
            if row['category'] in category_mapping:
                movie_id = row['tconst']
                if movie_id not in self.principals_dict:
                    self.principals_dict[movie_id] = []
                if pd.notna(row['nconst']):
                    self.principals_dict[movie_id].append(
                        (category_mapping[row['category']], row['nconst'])
                    )
        
        print("FeatureExtractor initialization complete")
    
    def get_feature_id(self, feature: str) -> int:
        if feature not in self.feature_to_id:
            self.feature_to_id[feature] = next(self.feature_id_counter)
            self.feature_counts[feature] = 1
        else:
            self.feature_counts[feature] += 1
        return self.feature_to_id[feature]
    
    def extract_features(self, imdb_id: str) -> Set[int]:
        """Extract all features for a movie"""
        feature_names = set()
        
        # Get movie details
        if imdb_id not in self.movies.index:
            return set()
        
        movie = self.movies.loc[imdb_id]
        
        # Process crew
        if imdb_id in self.crew.index:
            crew_row = self.crew.loc[imdb_id]
            for role in ['directors', 'writers']:
                if pd.notna(crew_row[role]):
                    for person_id in crew_row[role].split(','):
                        if person_id in self.names.index:
                            name = self.names.loc[person_id, 'primaryName']
                            if pd.notna(name):
                                feature = f"{role.title()[:-1]}:{name}"
                                feature_names.add(feature)
        
        # Process principals 
        if imdb_id in self.principals_dict:
            for category, person_id in self.principals_dict[imdb_id]:
                if person_id in self.names.index:
                    name = self.names.loc[person_id, 'primaryName']
                    if pd.notna(name):
                        feature = f"{category}:{name}"
                        feature_names.add(feature)
        
        # Process genres
        if pd.notna(movie['genres']):
            for genre in movie['genres'].split(','):
                feature = f"Genre:{genre}"
                feature_names.add(feature)
        
        # Process decade
        if not np.isnan(movie['startYear']):
            decade = (int(movie['startYear']) // 10) * 10
            feature = f"Decade:{decade}s"
            feature_names.add(feature)
        
        # Process runtimeMinutes
        if pd.notna(movie['runtimeMinutes']):
            runtime = pd.to_numeric(movie['runtimeMinutes'], errors='coerce')
            if not np.isnan(runtime):
                # Quantize runtime into bins
                if runtime < 60:
                    runtime_bin = "<60min"
                elif runtime < 90:
                    runtime_bin = "60-90min"
                elif runtime < 120:
                    runtime_bin = "90-120min"
                else:
                    runtime_bin = ">120min"
                feature = f"Runtime:{runtime_bin}"
                feature_names.add(feature)

        features = set()
        for feature in feature_names:
            features.add(self.get_feature_id(feature))
        
        return features

# %%
def clean_title(title):
    """Clean and validate a title string"""
    if pd.isna(title) or not isinstance(title, str): return None
    title = str(title).lower().strip()
    if not any(c.isalpha() for c in title): return None
    return title

def match_titles(netflix_titles: Dict[int, Dict[str, str]], 
                 imdb_movies: pd.DataFrame,
                 similarity_threshold: int = 90) -> Dict[int, str]:
    """Match Netflix titles to IMDB titles using optimized fuzzy matching"""
    print("Preparing dataframes...")
    
    # Convert Netflix titles to DataFrame
    netflix_df = pd.DataFrame.from_dict(netflix_titles, orient='index')
    netflix_df['year'] = pd.to_numeric(netflix_df['year'], errors='coerce')
    netflix_df = netflix_df.reset_index().rename(columns={'index': 'netflix_id'})
    
    # Clean Netflix titles
    netflix_df['clean_title'] = netflix_df['title'].apply(clean_title)
    netflix_df = netflix_df.dropna(subset=['clean_title'])
    print(f"Netflix movies (after cleaning): {len(netflix_df)} of {len(netflix_titles)} total")
    
    # Clean up IMDB movies DataFrame
    imdb_df = imdb_movies.copy()
    imdb_df['startYear'] = pd.to_numeric(imdb_df['startYear'], errors='coerce')
    imdb_df['clean_title'] = imdb_df['primaryTitle'].apply(clean_title)
    imdb_df = imdb_df.dropna(subset=['clean_title'])
    print(f"IMDB movies (after cleaning): {len(imdb_df)} of {len(imdb_movies)} total")
    
    netflix_to_imdb = {}
    total = len(netflix_df)
    
    print("Starting matching process...")
    
    # Match each Netflix movie id to an IMDB movie id via fuzzy match
    for idx, netflix_row in netflix_df.iterrows():
        if idx % 100 == 0:
            print(f"Processed {idx}/{total} titles ({(idx/total)*100:.1f}%)")
        
        netflix_id = netflix_row['netflix_id']
        netflix_year = netflix_row['year']
        netflix_title = netflix_row['clean_title']
        
        # Filter IMDB movies by year (±1 year) for faster lookup
        if pd.notna(netflix_year):
            year_mask = (imdb_df['startYear'] >= netflix_year - 1) & \
                        (imdb_df['startYear'] <= netflix_year + 1)
            candidates = imdb_df[year_mask]
        else:
            candidates = imdb_df
        
        # Find best match among candidates
        best_match = None
        best_score = 0
        
        for _, imdb_row in candidates.iterrows():
            imdb_title = imdb_row['clean_title']
            score = fuzz.ratio(netflix_title, imdb_title)
            
            if score > best_score and score >= similarity_threshold:
                best_score = score
                best_match = imdb_row['tconst']
        
        if best_match:
            netflix_to_imdb[netflix_id] = best_match
            if idx % 100 == 0:
                matched_title = imdb_df[imdb_df['tconst'] == best_match]['primaryTitle'].iloc[0]
                print(f"Matched: {netflix_row['title']} -> {matched_title} (score: {best_score})")
    
    print(f"\nMatching complete. Found {len(netflix_to_imdb)} matches.")
    return netflix_to_imdb

def print_sample_matches(netflix_titles, imdb_movies, netflix_to_imdb, n=5):
    """Print n sample matches to verify matching quality"""
    print("\nSample matches:")
    samples = list(netflix_to_imdb.items())[:n]
    
    for netflix_id, imdb_id in samples:
        netflix_info = netflix_titles[netflix_id]
        imdb_info = imdb_movies[imdb_movies['tconst'] == imdb_id].iloc[0]
        print(f"\nNetflix: {netflix_info['title']} ({netflix_info['year']})")
        print(f"IMDB:    {imdb_info['primaryTitle']} ({imdb_info['startYear']})")
        print(f"IMDB ID: {imdb_id}")

# %% [markdown]
# ## Extract Features

# %%
print("Loading data...")
netflix_titles = load_netflix_titles()
imdb_data = load_imdb_data()

# %% [markdown]
# We can see here the netflix dataset only goes up to 2005 so we will then prune out all >2005 movies

# %%
max(int(netflix_titles[entry]['year']) for entry in netflix_titles if netflix_titles[entry]['year'].isdigit())

# %% [markdown]
# Create mapping between Netflix and IMDB movie id's

# %%
# # Compute netflix to imdb id mapping
# print("Matching titles...")
# netflix_to_imdb = match_titles(netflix_titles, imdb_data['movies'])
# with open('data/netflix_to_imdb.json', 'w') as f: json.dump(netflix_to_imdb, f)  
# print_sample_matches(netflix_titles, imdb_data['movies'], netflix_to_imdb)
# print(f"Matched {len(netflix_to_imdb)} movies")

# import precomputed mapping
with open('data/netflix_to_imdb.json', 'r') as f: netflix_to_imdb = json.load(f)

# %% [markdown]
# Use the id mappings to extract features for each movie (cast member, country, genre, etc) from the IMDB dataset

# %%
print("Extracting features...")
extractor = FeatureExtractor(imdb_data, netflix_to_imdb)
movie_features = {}

total = len(netflix_to_imdb)
for idx, (netflix_id, imdb_id) in enumerate(netflix_to_imdb.items(), 1):
    if idx % 100 == 0:
        print(f"Processing movie {idx}/{total} ({idx/total*100:.1f}%)")
    features = extractor.extract_features(imdb_id)
    if features:
        movie_features[netflix_id] = features

# %% [markdown]
# ## Prune Features
# - Remove features below 20 occurrences
# - Assign new sequential id's to the features instead of using IMDB id's

# %%
MIN_OCCURRENCES = 20

# %%
print("Pruning features...")
features_to_keep = {
    feature for feature, count in extractor.feature_counts.items() 
    if count >= MIN_OCCURRENCES
}

# Rebuild the feature IDs with new sequential IDs
feature_to_id = {
    feature: idx for idx, feature in enumerate(sorted(features_to_keep), start=1)
}

pruned_features = {}
for netflix_id, old_feature_ids in movie_features.items():
    # Map old feature IDs to their feature names and then to new IDs
    kept_features = {
        feature_to_id[feature_name]  # Get new ID
        for feature_name, old_id in extractor.feature_to_id.items()  # Get name from old ID
        if feature_name in features_to_keep and old_id in old_feature_ids  # Check both conditions
    }
    if kept_features:
        pruned_features[netflix_id] = sorted(kept_features)

# %% [markdown]
# ## Save Features

# %%
# Create output directory if it doesn't exist
output_dir = os.path.join(DATA_PATH, "processed")
os.makedirs(output_dir, exist_ok=True)

print("Saving results...")
with open(os.path.join(output_dir, f'feature_mapping_{MIN_OCCURRENCES}.pickle'), 'wb') as f:
    pickle.dump({
        'feature_to_id': feature_to_id,
        'id_to_feature': {v: k for k, v in feature_to_id.items()}
    }, f)

with open(os.path.join(output_dir, f'movie_features_{MIN_OCCURRENCES}.pickle'), 'wb') as f:
    pickle.dump(pruned_features, f)

print(f"Done! Processed {len(pruned_features)} movies with {len(feature_to_id)} features")
print(f"Results saved in {output_dir}")

# %% [markdown]
# ## Save Feature Counts

# %%
def save_feature_frequencies(extractor, feature_to_id, output_dir):
    feature_frequencies = {}
    for feature_name, count in extractor.feature_counts.items():
        if feature_name in feature_to_id:
            new_id = feature_to_id[feature_name]
            feature_frequencies[new_id] = count

    frequencies_path = os.path.join(output_dir, f'feature_frequencies_{MIN_OCCURRENCES}.pickle')
    with open(frequencies_path, 'wb') as f:
        pickle.dump(feature_frequencies, f)

save_feature_frequencies(extractor, feature_to_id, output_dir)

# %% [markdown]
# ## Import the Data (Sanity Check)

# %%
feature_mapping = pd.read_pickle(f'{DATA_PATH}/processed/feature_mapping_{MIN_OCCURRENCES}.pickle')
feature_to_id = feature_mapping['feature_to_id']
# movie_features = pd.read_pickle(f'data/processed/movie_features_{MIN_OCCURRENCES}.pickle')

# Map the most popular feature IDs to their features and print
feature_frequencies = pd.read_pickle(f'{DATA_PATH}/processed/feature_frequencies_{MIN_OCCURRENCES}.pickle')
sorted_features = sorted(feature_frequencies.items(), key=lambda x: x[1], reverse=True)
id_to_feature = {v: k for k, v in feature_to_id.items()}

for feature_id, count in sorted_features:
    print(f"{id_to_feature[feature_id]}: {count} occurrences")
# Out:
# Runtime:90-120min: 6013 occurrences
# Genre:Drama: 5308 occurrences
# Genre:Comedy: 3473 occurrences
# Decade:1990s: 2906 occurrences
# Decade:2000s: 2782 occurrences
# Genre:Romance: 2062 occurrences
# Genre:Crime: 1748 occurrences
# Runtime:60-90min: 1732 occurrences
# Genre:Action: 1723 occurrences
# Runtime:>120min: 1601 occurrences
# Decade:1980s: 1380 occurrences
# Genre:Thriller: 1223 occurrences
# Genre:Adventure: 1112 occurrences
# Genre:Horror: 931 occurrences
# Decade:1970s: 863 occurrences
# Genre:Mystery: 697 occurrences
# Decade:1960s: 601 occurrences
# Genre:Fantasy: 550 occurrences
# Genre:Sci-Fi: 540 occurrences
# Genre:Family: 491 occurrences
# Genre:Documentary: 442 occurrences
# Decade:1950s: 439 occurrences
# Genre:Biography: 425 occurrences
# Genre:Music: 365 occurrences
# Genre:War: 297 occurrences
# Genre:History: 293 occurrences
# Decade:1940s: 270 occurrences
# Genre:Musical: 261 occurrences
# Genre:Animation: 210 occurrences
# Genre:Sport: 201 occurrences
# Genre:Western: 188 occurrences
# Decade:1930s: 144 occurrences
# Composer:Jerry Goldsmith: 107 occurrences
# Genre:Film-Noir: 97 occurrences
# Composer:Elmer Bernstein: 85 occurrences
# Composer:James Horner: 80 occurrences
# Composer:Alan Silvestri: 64 occurrences
# Composer:James Newton Howard: 63 occurrences
# Composer:John Williams: 63 occurrences
# Cast:John Wayne: 60 occurrences
# Composer:Hans Zimmer: 59 occurrences
# Composer:Mark Isham: 59 occurrences
# Composer:David Newman: 58 occurrences
# Cast:Gene Hackman: 54 occurrences
# Runtime:<60min: 54 occurrences
# Composer:Graeme Revell: 53 occurrences
# Composer:Maurice Jarre: 51 occurrences
# Decade:1920s: 50 occurrences
# Composer:Carter Burwell: 48 occurrences
# Composer:Randy Edelman: 47 occurrences
# Cast:Michael Caine: 46 occurrences
# Composer:Ennio Morricone: 46 occurrences
# Composer:Howard Shore: 45 occurrences
# Cast:Harvey Keitel: 45 occurrences
# Composer:Michael Kamen: 45 occurrences
# Composer:John Barry: 45 occurrences
# Composer:Danny Elfman: 45 occurrences
# Cast:Robert De Niro: 44 occurrences
# Composer:Bill Conti: 44 occurrences
# Cast:Amitabh Bachchan: 44 occurrences
# Composer:George Fenton: 44 occurrences
# Cast:Clint Eastwood: 44 occurrences
# Cast:Robert Duvall: 43 occurrences
# Writer:Ben Hecht: 43 occurrences
# Composer:Georges Delerue: 42 occurrences
# Cast:Sean Connery: 41 occurrences
# Composer:Christopher Young: 41 occurrences
# Composer:John Debney: 41 occurrences
# Composer:Lalo Schifrin: 41 occurrences
# Writer:William Shakespeare: 40 occurrences
# Composer:Basil Poledouris: 40 occurrences
# Producer:Scott Rudin: 40 occurrences
# Cast:Jeff Bridges: 39 occurrences
# Composer:Thomas Newman: 39 occurrences
# Cast:Bruce Willis: 39 occurrences
# Cast:Dennis Hopper: 39 occurrences
# Writer:Woody Allen: 38 occurrences
# Cast:Cary Grant: 38 occurrences
# Producer:Brian Grazer: 38 occurrences
# Composer:Trevor Jones: 37 occurrences
# Director:Alfred Hitchcock: 37 occurrences
# Producer:Arnon Milchan: 37 occurrences
# Composer:Anu Malik: 37 occurrences
# Cast:Burt Lancaster: 37 occurrences
# Cast:Samuel L. Jackson: 37 occurrences
# Composer:Henry Mancini: 36 occurrences
# Cast:Burt Reynolds: 36 occurrences
# Cast:Christopher Walken: 36 occurrences
# Producer:Joel Silver: 36 occurrences
# Cast:Walter Matthau: 36 occurrences
# Cast:James Stewart: 36 occurrences
# Cast:Jack Nicholson: 35 occurrences
# Director:Woody Allen: 35 occurrences
# Composer:Alfred Newman: 35 occurrences
# Cast:Danny DeVito: 35 occurrences
# Composer:Dimitri Tiomkin: 35 occurrences
# Cast:Dan Aykroyd: 35 occurrences
# Cast:Robin Williams: 34 occurrences
# Cast:Donald Sutherland: 34 occurrences
# Cast:Willem Dafoe: 34 occurrences
# Composer:Dave Grusin: 34 occurrences
# Cast:John Goodman: 34 occurrences
# Cast:John Travolta: 34 occurrences
# Cast:Nicolas Cage: 34 occurrences
# Cast:Woody Allen: 33 occurrences
# Producer:Roger Birnbaum: 33 occurrences
# Cast:Dennis Quaid: 32 occurrences
# Cast:Kurt Russell: 32 occurrences
# Cast:James Woods: 32 occurrences
# Cast:Bill Pullman: 32 occurrences
# Cast:Mel Gibson: 32 occurrences
# Cast:Michelle Pfeiffer: 32 occurrences
# Cast:Ed Harris: 32 occurrences
# Producer:Elie Samaha: 31 occurrences
# Cast:Rip Torn: 31 occurrences
# Cast:Charles Durning: 31 occurrences
# Cast:Bruce Dern: 31 occurrences
# Producer:John Davis: 31 occurrences
# Cast:Susan Sarandon: 31 occurrences
# Cast:Robert Loggia: 31 occurrences
# Writer:Stephen King: 31 occurrences
# Cast:Morgan Freeman: 31 occurrences
# Cast:Nick Nolte: 31 occurrences
# Composer:Stewart Copeland: 31 occurrences
# Cast:Keanu Reeves: 30 occurrences
# Cast:Kirk Douglas: 30 occurrences
# Cast:Jack Lemmon: 30 occurrences
# Cast:Sylvester Stallone: 30 occurrences
# Cast:Alec Baldwin: 30 occurrences
# Cast:Kiefer Sutherland: 30 occurrences
# Cast:Steve Martin: 30 occurrences
# Cast:Kevin Bacon: 30 occurrences
# Cast:Christian Slater: 30 occurrences
# Cast:Liam Neeson: 30 occurrences
# Cast:Daryl Hannah: 30 occurrences
# Cast:Gabriel Byrne: 30 occurrences
# Cast:Denzel Washington: 30 occurrences
# Composer:Marc Shaiman: 30 occurrences
# Cast:James Caan: 30 occurrences
# Cast:Anupam Kher: 30 occurrences
# Cast:Anthony Hopkins: 30 occurrences
# Cast:Tom Berenger: 29 occurrences
# Cast:Charles Bronson: 29 occurrences
# Cast:John Cusack: 29 occurrences
# Cast:Kevin Pollak: 29 occurrences
# Cast:John Heard: 29 occurrences
# Cast:Jackie Chan: 29 occurrences
# Cast:James Coburn: 29 occurrences
# Cast:Bill Paxton: 29 occurrences
# Composer:Max Steiner: 29 occurrences
# Cast:Keith David: 29 occurrences
# Cast:John Turturro: 29 occurrences
# Cast:John Hurt: 28 occurrences
# Cast:Brian Cox: 28 occurrences
# Cast:Sean Penn: 28 occurrences
# Cast:Steve Buscemi: 28 occurrences
# Cast:Vincent D'Onofrio: 28 occurrences
# Cast:Laurence Fishburne: 28 occurrences
# Composer:Bernard Herrmann: 28 occurrences
# Cast:Harrison Ford: 28 occurrences
# Cast:Kevin Spacey: 28 occurrences
# Cast:Dan Hedaya: 28 occurrences
# Cast:Julia Roberts: 28 occurrences
# Cast:Paul Newman: 28 occurrences
# Producer:Jerry Bruckheimer: 28 occurrences
# Cast:Richard Dreyfuss: 28 occurrences
# Cast:Andy Lau: 28 occurrences
# Cast:John Malkovich: 28 occurrences
# Producer:Menahem Golan: 28 occurrences
# Cast:Tom Hanks: 28 occurrences
# Writer:Jing Wong: 27 occurrences
# Cast:Fred Ward: 27 occurrences
# Cast:Sharon Stone: 27 occurrences
# Cast:Ben Johnson: 27 occurrences
# Cast:Carol Kane: 27 occurrences
# Cast:Stephen Tobolowsky: 27 occurrences
# Cast:Billy Bob Thornton: 27 occurrences
# Cast:Jennifer Jason Leigh: 27 occurrences
# Cast:Richard Gere: 27 occurrences
# Cast:Bob Hoskins: 27 occurrences
# Composer:Rachel Portman: 27 occurrences
# Cast:Charlie Sheen: 27 occurrences
# Cast:Gregory Peck: 27 occurrences
# Cast:Malcolm McDowell: 27 occurrences
# Composer:Mark Mothersbaugh: 27 occurrences
# Cast:Seymour Cassel: 27 occurrences
# Cast:Eddie Murphy: 27 occurrences
# Cast:John Carradine: 27 occurrences
# Composer:Bruce Broughton: 27 occurrences
# Cast:Dustin Hoffman: 27 occurrences
# Producer:Yoram Globus: 27 occurrences
# Cast:Meg Ryan: 27 occurrences
# Cast:Tommy Lee Jones: 27 occurrences
# Cast:Christopher Lee: 27 occurrences
# Cast:Jim Belushi: 26 occurrences
# Cast:Keenan Wynn: 26 occurrences
# Cast:Whoopi Goldberg: 26 occurrences
# Cast:Melanie Griffith: 26 occurrences
# Composer:Patrick Williams: 26 occurrences
# Composer:Franz Waxman: 26 occurrences
# Cast:Henry Fonda: 26 occurrences
# Cast:John C. McGinley: 26 occurrences
# Cast:Bill Murray: 26 occurrences
# Cast:Chow Yun-Fat: 26 occurrences
# Cast:Anthony Quinn: 26 occurrences
# Cast:Sandra Bullock: 26 occurrences
# Cast:Julianne Moore: 26 occurrences
# Cast:Shah Rukh Khan: 26 occurrences
# Cast:Harry Dean Stanton: 26 occurrences
# Cast:William Hurt: 26 occurrences
# Writer:Jacques Monteux: 26 occurrences
# Writer:John Hughes: 26 occurrences
# Cast:Christopher McDonald: 26 occurrences
# Cast:M. Emmet Walsh: 26 occurrences
# Composer:Richard Gibbs: 26 occurrences
# Cast:J.T. Walsh: 26 occurrences
# Cast:Charlton Heston: 26 occurrences
# Cast:Humphrey Bogart: 26 occurrences
# Director:Clint Eastwood: 26 occurrences
# Cast:Joe Pantoliano: 26 occurrences
# Cast:Jack Warden: 26 occurrences
# Composer:John Powell: 26 occurrences
# Cast:Randy Quaid: 26 occurrences
# Cast:Meryl Streep: 25 occurrences
# Cast:Val Kilmer: 25 occurrences
# Producer:Robert Greenhut: 25 occurrences
# Producer:Edward R. Pressman: 25 occurrences
# Cast:Christopher Lloyd: 25 occurrences
# Cast:Jason Robards: 25 occurrences
# Producer:Lawrence Gordon: 25 occurrences
# Cast:Mickey Rourke: 25 occurrences
# Cast:Robert Redford: 25 occurrences
# Producer:Roger Corman: 25 occurrences
# Composer:Mychael Danna: 25 occurrences
# Cast:Ned Beatty: 25 occurrences
# Cast:Drew Barrymore: 25 occurrences
# Cast:James Earl Jones: 25 occurrences
# Cast:Geoffrey Lewis: 25 occurrences
# Producer:Neal H. Moritz: 25 occurrences
# Cast:Ian Holm: 25 occurrences
# Cast:Rod Steiger: 25 occurrences
# Cast:Michael Rapaport: 25 occurrences
# Cast:Diane Keaton: 24 occurrences
# Cast:Arnold Schwarzenegger: 24 occurrences
# Cast:Brad Dourif: 24 occurrences
# Cast:Michael Douglas: 24 occurrences
# Cast:Gérard Depardieu: 24 occurrences
# Cast:Brion James: 24 occurrences
# Cast:Martin Sheen: 24 occurrences
# Composer:Christophe Beck: 24 occurrences
# Producer:James G. Robinson: 24 occurrences
# Composer:George S. Clinton: 24 occurrences
# Cast:Jamie Lee Curtis: 24 occurrences
# Cast:Matt Dillon: 24 occurrences
# Cast:Philip Seymour Hoffman: 24 occurrences
# Cast:Faye Dunaway: 24 occurrences
# Cast:Max von Sydow: 24 occurrences
# Cast:Michael McKean: 24 occurrences
# Cast:Danny Glover: 24 occurrences
# Cast:Al Pacino: 24 occurrences
# Cast:Richard Jenkins: 24 occurrences
# Composer:Trevor Rabin: 24 occurrences
# Cast:Anne Bancroft: 24 occurrences
# Composer:Miles Goodman: 24 occurrences
# Cast:Jean-Claude Van Damme: 24 occurrences
# Producer:Irwin Winkler: 24 occurrences
# Cast:Roddy McDowall: 24 occurrences
# Composer:Michel Colombier: 24 occurrences
# Cast:Antonio Banderas: 24 occurrences
# Cast:Tom Cruise: 24 occurrences
# Cast:Udo Kier: 24 occurrences
# Cast:Demi Moore: 24 occurrences
# Cast:Amrish Puri: 24 occurrences
# Cast:Anjelica Huston: 24 occurrences
# Cast:Pam Grier: 24 occurrences
# Cast:Robert Downey Jr.: 24 occurrences
# Cast:Stanley Tucci: 24 occurrences
# Cast:Nicole Kidman: 24 occurrences
# Producer:Jing Wong: 23 occurrences
# Cast:William H. Macy: 23 occurrences
# Producer:Mark Johnson: 23 occurrences
# Cast:Michael Madsen: 23 occurrences
# Cast:Alec Guinness: 23 occurrences
# Cast:Christopher Plummer: 23 occurrences
# Cast:Danny Aiello: 23 occurrences
# Cast:Sidney Poitier: 23 occurrences
# Cast:Robert Mitchum: 23 occurrences
# Cast:Michael J. Fox: 23 occurrences
# Cast:Mary Steenburgen: 23 occurrences
# Cast:Uma Thurman: 23 occurrences
# Cast:Johnny Depp: 23 occurrences
# Cast:Joan Cusack: 23 occurrences
# Cast:Ben Affleck: 23 occurrences
# Composer:Michael Small: 23 occurrences
# Cast:Eric Roberts: 23 occurrences
# Cast:Kevin Kline: 23 occurrences
# Composer:Harry Gregson-Williams: 23 occurrences
# Cast:David Paymer: 23 occurrences
# Cast:Gary Busey: 23 occurrences
# Cast:Ellen Barkin: 23 occurrences
# Cast:Wesley Snipes: 23 occurrences
# Cast:Peter Sellers: 23 occurrences
# Cast:James Spader: 23 occurrences
# Cast:Richard Harris: 23 occurrences
# Cast:George Segal: 23 occurrences
# Cast:Jon Voight: 23 occurrences
# Cast:James Garner: 23 occurrences
# Cast:Goldie Hawn: 23 occurrences
# Composer:Terence Blanchard: 23 occurrences
# Producer:Brad Krevoy: 23 occurrences
# Cast:Denis Leary: 23 occurrences
# Composer:Miklós Rózsa: 23 occurrences
# Cast:Sam Neill: 23 occurrences
# Cast:Ving Rhames: 23 occurrences
# Cast:Wallace Shawn: 23 occurrences
# Cast:Christina Ricci: 23 occurrences
# Cast:Kirsten Dunst: 23 occurrences
# Cast:Elvis Presley: 23 occurrences
# Cast:Maury Chaykin: 23 occurrences
# Cast:Joe Mantegna: 23 occurrences
# Cast:Gary Oldman: 22 occurrences
# Cast:Bridget Fonda: 22 occurrences
# Cast:Tom Wilkinson: 22 occurrences
# Cast:Jeff Goldblum: 22 occurrences
# Cast:James Rebhorn: 22 occurrences
# Composer:Patrick Doyle: 22 occurrences
# Cast:Pierce Brosnan: 22 occurrences
# Cast:Brad Pitt: 22 occurrences
# Cast:Hugh Grant: 22 occurrences
# Cast:Tim Robbins: 22 occurrences
# Cast:Joss Ackland: 22 occurrences
# Cast:Paul Dooley: 22 occurrences
# Cast:John Cleese: 22 occurrences
# Cast:Alfred Molina: 22 occurrences
# Cast:Denholm Elliott: 22 occurrences
# Cast:Peter Boyle: 22 occurrences
# Cast:Johny Lever: 22 occurrences
# Cast:Kevin Costner: 22 occurrences
# Cast:James Remar: 22 occurrences
# Cast:Kathy Bates: 22 occurrences
# Writer:Neil Simon: 22 occurrences
# Cast:Ernest Borgnine: 22 occurrences
# Cast:Dermot Mulroney: 22 occurrences
# Cast:Martin Balsam: 22 occurrences
# Cast:Kim Basinger: 22 occurrences
# Cast:Anil Kapoor: 22 occurrences
# Cast:Paresh Rawal: 22 occurrences
# Cast:Andy Garcia: 22 occurrences
# Cast:Laurence Olivier: 22 occurrences
# Cast:Ben Stiller: 22 occurrences
# Producer:Ron Miller: 22 occurrences
# Cast:Dom DeLuise: 22 occurrences
# Composer:Edward Shearmur: 22 occurrences
# Producer:Alain Sarde: 22 occurrences
# Cast:Glenn Close: 22 occurrences
# Cast:Richard Widmark: 21 occurrences
# Writer:David Mamet: 21 occurrences
# Cast:Mia Farrow: 21 occurrences
# Writer:Billy Wilder: 21 occurrences
# Cast:William Holden: 21 occurrences
# Cast:Tim Roth: 21 occurrences
# Cast:Matthew Broderick: 21 occurrences
# Cast:Jack Palance: 21 occurrences
# Cast:Ethan Hawke: 21 occurrences
# Cast:Frank Sinatra: 21 occurrences
# Producer:Tim Bevan: 21 occurrences
# Cast:Matt Damon: 21 occurrences
# Cast:Ben Kingsley: 21 occurrences
# Cast:John Leguizamo: 21 occurrences
# Cast:Jodie Foster: 21 occurrences
# Cast:Donald Pleasence: 21 occurrences
# Producer:Christine Vachon: 21 occurrences
# Cast:Dabney Coleman: 21 occurrences
# Cast:Alfre Woodard: 21 occurrences
# Cast:Anthony LaPaglia: 21 occurrences
# Cast:Kathleen Turner: 21 occurrences
# Cast:Lee Marvin: 21 occurrences
# Cast:Anthony Chau-Sang Wong: 21 occurrences
# Cast:Bruce McGill: 21 occurrences
# Cast:James Cromwell: 21 occurrences
# Cast:Michael Keaton: 21 occurrences
# Cast:Delroy Lindo: 21 occurrences
# Cast:Ewan McGregor: 21 occurrences
# Cast:Nastassja Kinski: 21 occurrences
# Cast:Richard Masur: 21 occurrences
# Cast:Heather Graham: 21 occurrences
# Cast:Jennifer Tilly: 21 occurrences
# Cast:Jane Fonda: 21 occurrences
# Cast:Jonathan Pryce: 21 occurrences
# Cast:Sean Astin: 21 occurrences
# Composer:Angelo Badalamenti: 21 occurrences
# Cast:Paul Sorvino: 21 occurrences
# Cast:David Arquette: 20 occurrences
# Cast:Harry Morgan: 20 occurrences
# Cast:Robert Wagner: 20 occurrences
# Cast:Peter Falk: 20 occurrences
# Director:Blake Edwards: 20 occurrences
# Cast:Barbara Hershey: 20 occurrences
# Cast:Tom Sizemore: 20 occurrences
# Composer:Mark Mancina: 20 occurrences
# Cast:Patrick Swayze: 20 occurrences
# Composer:Rolfe Kent: 20 occurrences
# Cast:James Mason: 20 occurrences
# Writer:William Goldman: 20 occurrences
# Cast:Brian Dennehy: 20 occurrences
# Cast:George Kennedy: 20 occurrences
# Cast:Forest Whitaker: 20 occurrences
# Cast:Aidan Quinn: 20 occurrences
# Producer:Eric Fellner: 20 occurrences
# Cast:Michael Rooker: 20 occurrences
# Cast:Elisabeth Shue: 20 occurrences
# Cast:Pat Hingle: 20 occurrences
# Cast:Steve McQueen: 20 occurrences
# Cast:Andie MacDowell: 20 occurrences
# Writer:Akira Kurosawa: 20 occurrences
# Cast:Alan Arkin: 20 occurrences
# Cast:Jeff Daniels: 20 occurrences
# Cast:Brendan Fraser: 20 occurrences
# Cast:John C. Reilly: 20 occurrences
# Composer:Philippe Sarde: 20 occurrences
# Cast:Cuba Gooding Jr.: 20 occurrences
# Producer:Richard D. Zanuck: 20 occurrences
# Cast:Ajay Devgn: 20 occurrences
# Director:William Wyler: 20 occurrences
# Director:Norman Jewison: 20 occurrences
# Director:John Huston: 20 occurrences
# Producer:Michael Shamberg: 20 occurrences
# Cast:Robert Prosky: 20 occurrences
# Cast:Scott Glenn: 20 occurrences
# Cast:Om Puri: 20 occurrences
# Composer:Marvin Hamlisch: 20 occurrences
# Composer:Michel Legrand: 20 occurrences
# Cast:Terence Stamp: 20 occurrences
# Cast:Luis Guzmán: 20 occurrences
# Cast:Rosanna Arquette: 20 occurrences
# Cast:Tom Skerritt: 20 occurrences
# Cast:John Candy: 20 occurrences
# Producer:Dino De Laurentiis: 20 occurrences
# Cast:Michael Gambon: 20 occurrences
# Director:Brian De Palma: 20 occurrences
# Cast:Oliver Platt: 20 occurrences
# Cast:Gwyneth Paltrow: 20 occurrences
# Cast:Leslie Cheung: 20 occurrences
# Cast:Jeremy Piven: 20 occurrences
# Cast:Hector Elizondo: 20 occurrences
# Producer:Robert Simonds: 20 occurrences
# Producer:Hal B. Wallis: 20 occurrences
# Cast:Lance Henriksen: 20 occurrences
# Cast:Patricia Clarkson: 20 occurrences
# Cast:Sigourney Weaver: 20 occurrences
